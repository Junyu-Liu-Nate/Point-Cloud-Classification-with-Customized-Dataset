# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

projectPath = '/content/drive/MyDrive/BVC/starter_project/'
codePath = 'pointnet_pytorch/'
os.chdir(projectPath + codePath)

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/drive/MyDrive/BVC/starter_project/pointnet_pytorch
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for pointnet
# ...

# %%
trainPath = 'utils/'
os.chdir(projectPath + codePath + trainPath)

# %%
# !pip install trimesh plyfile
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.5/686.5 kB 7.2 MB/s eta 0:00:00
# ...

# %%
# !python train_classification.py --dataset '../../AbstractGeometries/' --nepoch=20 --dataset_type 'abstractGeometries' --batchSize=128
# Out:
# Namespace(batchSize=128, num_points=2500, workers=4, nepoch=20, outf='cls', model='', dataset='../../AbstractGeometries/', dataset_type='abstractGeometries', feature_transform=False)
# Random Seed:  3549
# {'sphere': 0, 'cube': 1, 'cylinder': 2, 'torus': 3, 'pyramid': 4, 'spiral': 5, 'torusKnot': 6, 'doubleCone': 7}
# {'sphere': 0, 'cube': 1, 'cylinder': 2, 'torus': 3, 'pyramid': 4, 'spiral': 5, 'torusKnot': 6, 'doubleCone': 7}
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 4000 1600
# classes 8
# ...
